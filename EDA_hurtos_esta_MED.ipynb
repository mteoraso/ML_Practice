# %% [markdown]
# <a href="https://colab.research.google.com/github/mteoraso/DataScience_practice/blob/EDA-Projects/EDA_hurtos_esta_MED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Importar librerias

import pandas as pd   ## Libreria Pandas para analisis de datos
import matplotlib.pyplot as plt   ## Libreria Matplolib para realizar graficas
import seaborn as sns    ## Libreria Seaborn para realizar graficas estadisticas

# %%
## Cargar la base de datos

DF_hurtos_establecimiento_MED = pd.read_csv("/content/drive/MyDrive/Datasets/hurto_a_establecimiento_comercial.csv")

# %%
DF_hurtos_establecimiento_MED
# Out:
#                          fecha_hecho  cantidad   latitud   longitud      sexo  \
# 0      2017-01-01T16:00:00.000-05:00       1.0  6.250662 -75.572558  Sin dato
# 1      2017-01-01T11:00:00.000-05:00       1.0  6.257235 -75.599740  Sin dato
# 2      2017-01-01T14:15:00.000-05:00       1.0  6.301532 -75.563771  Sin dato
# 3      2017-01-01T16:00:00.000-05:00       1.0  6.250662 -75.572558  Sin dato
# 4      2017-01-01T14:15:00.000-05:00       1.0  6.301532 -75.563771  Sin dato
# ...                              ...       ...       ...        ...       ...
# 54394  2023-11-27T09:30:00.000-05:00       1.0       NaN        NaN  Sin dato
# 54395  2023-11-28T12:00:00.000-05:00       1.0       NaN        NaN  Sin dato
# 54396  2023-11-28T17:50:00.000-05:00       1.0       NaN        NaN  Sin dato
# 54397  2023-11-29T13:30:00.000-05:00       1.0       NaN        NaN  Sin dato
# 54398  2023-11-30T07:30:00.000-05:00       1.0       NaN        NaN  Sin dato
#
# ...

# %% [markdown]
# # **Analisis Exploratorio de Datos**

# %%
type(DF_hurtos_establecimiento_MED)
# Out:
# pandas.core.frame.DataFrame

# %%
## Comando SHAPE para validar cuantas filas y cuantas columnas tiene el dataframe
DF_hurtos_establecimiento_MED.shape
# Out:
# (54399, 36)

# %%
## Comando COLUMNS para validar cuales columnas tenemos en nuestro dataframe
DF_hurtos_establecimiento_MED.columns
# Out:
# Index(['fecha_hecho', 'cantidad', 'latitud', 'longitud', 'sexo', 'edad',
#        'estado_civil', 'grupo_actor', 'actividad_delictiva', 'parentesco',
#        'ocupacion', 'discapacidad', 'grupo_especial', 'medio_transporte',
#        'nivel_academico', 'testigo', 'conducta', 'modalidad',
#        'caracterizacion', 'conducta_especial', 'arma_medio', 'articulo_penal',
#        'categoria_penal', 'nombre_barrio', 'codigo_barrio', 'codigo_comuna',
#        'lugar', 'sede_receptora', 'bien', 'categoria_bien', 'grupo_bien',
#        'modelo', 'color', 'permiso', 'unidad_medida', 'fecha_ingestion'],
#       dtype='object')

# %%
## Comando DESCRIBE para validar estadisticos descriptivos basicos
## para variables cuantitativas
DF_hurtos_establecimiento_MED.describe()
# Out:
#        cantidad       latitud      longitud          edad        modelo
# count   54399.0  49354.000000  49354.000000  54399.000000  54399.000000
# mean        1.0      6.245509    -75.573866      0.893950     -0.852405
# std         0.0      0.030707      0.680971      8.504413     17.209704
# min         1.0      4.615156    -75.706583     -1.000000     -1.000000
# 25%         1.0      6.229913    -75.587326     -1.000000     -1.000000
# 50%         1.0      6.247568    -75.573574     -1.000000     -1.000000
# 75%         1.0      6.259708    -75.566180     -1.000000     -1.000000
# max         1.0      7.876824     75.607180     79.000000   2014.000000

# %%
# !pip install skimpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 121.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 125.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 88.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
# ...

# %%
# Libreria Skimpy permite realizar estadistiscos descriptivos de variables categoricas
from skimpy import skim

skim(DF_hurtos_establecimiento_MED)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1e9967205b28> in <cell line: 0>()
#       2 from skimpy import skim
#       3
# ----> 4 skim(dataframe_hurtos_establecimiento_MED)
#
# NameError: name 'dataframe_hurtos_establecimiento_MED' is not defined

# %%
## Al aplicar el comando INFO nos retorna el tipo de dato de cada columna
DF_hurtos_establecimiento_MED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54399 entries, 0 to 54398
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha_hecho          54399 non-null  object
#  1   cantidad             54399 non-null  float64
#  2   latitud              49354 non-null  float64
#  3   longitud             49354 non-null  float64
#  4   sexo                 54399 non-null  object
#  5   edad                 54399 non-null  int64
#  6   estado_civil         54399 non-null  object
#  7   grupo_actor          54399 non-null  object
#  8   actividad_delictiva  54399 non-null  object
#  9   parentesco           54399 non-null  object
#  10  ocupacion            54399 non-null  object
#  11  discapacidad         54399 non-null  object
#  12  grupo_especial       54399 non-null  object
#  13  medio_transporte     54399 non-null  object
#  14  nivel_academico      54399 non-null  object
# ...

# %%
## Transformar el tipo de datos de algunas columnas para ahorrar espacio
DF_hurtos_establecimiento_MED = DF_hurtos_establecimiento_MED.astype({"cantidad":"int32"})
DF_hurtos_establecimiento_MED = DF_hurtos_establecimiento_MED.astype({"edad":"int32"})
DF_hurtos_establecimiento_MED = DF_hurtos_establecimiento_MED.astype({"sexo":"category"})

# %%
DF_hurtos_establecimiento_MED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54399 entries, 0 to 54398
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha_hecho          54399 non-null  object
#  1   cantidad             54399 non-null  int32
#  2   latitud              49354 non-null  float64
#  3   longitud             49354 non-null  float64
#  4   sexo                 54399 non-null  category
#  5   edad                 54399 non-null  int32
#  6   estado_civil         54399 non-null  object
#  7   grupo_actor          54399 non-null  object
#  8   actividad_delictiva  54399 non-null  object
#  9   parentesco           54399 non-null  object
#  10  ocupacion            54399 non-null  object
#  11  discapacidad         54399 non-null  object
#  12  grupo_especial       54399 non-null  object
#  13  medio_transporte     54399 non-null  object
#  14  nivel_academico      54399 non-null  object
# ...

# %%
## Identificar valores nulos
DF_hurtos_establecimiento_MED.isnull()
# Out:
#        fecha_hecho  cantidad  latitud  longitud   sexo   edad  estado_civil  \
# 0            False     False    False     False  False  False         False
# 1            False     False    False     False  False  False         False
# 2            False     False    False     False  False  False         False
# 3            False     False    False     False  False  False         False
# 4            False     False    False     False  False  False         False
# ...            ...       ...      ...       ...    ...    ...           ...
# 54394        False     False     True      True  False  False         False
# 54395        False     False     True      True  False  False         False
# 54396        False     False     True      True  False  False         False
# 54397        False     False     True      True  False  False         False
# 54398        False     False     True      True  False  False         False
#
# ...

# %%
DF_hurtos_establecimiento_MED.isnull().sum()
# Out:
# fecha_hecho               0
# cantidad                  0
# latitud                5045
# longitud               5045
# sexo                      0
# edad                      0
# estado_civil              0
# grupo_actor               0
# actividad_delictiva       0
# parentesco                0
# ocupacion                 0
# discapacidad              0
# grupo_especial            0
# medio_transporte          0
# nivel_academico           0
# testigo                   0
# conducta                  0
# modalidad                 0
# caracterizacion           0
# conducta_especial         0
# arma_medio                0
# articulo_penal            0
# categoria_penal           0
# nombre_barrio             0
# codigo_barrio             0
# codigo_comuna             0
# lugar                     0
# sede_receptora            0
# bien                      0
# categoria_bien            0
# grupo_bien                0
# modelo                    0
# color                     0
# ...

# %%
## Comando TAIL para visualizar ultimos registros
DF_hurtos_establecimiento_MED.tail(20)
# Out:
#                          fecha_hecho  cantidad  latitud  longitud      sexo  \
# 54379  2023-11-08T02:30:00.000-05:00         1      NaN       NaN  Sin dato
# 54380  2023-11-11T01:30:00.000-05:00         1      NaN       NaN  Sin dato
# 54381  2023-11-11T16:15:00.000-05:00         1      NaN       NaN  Sin dato
# 54382  2023-11-11T16:30:00.000-05:00         1      NaN       NaN  Sin dato
# 54383  2023-11-11T22:00:00.000-05:00         1      NaN       NaN  Sin dato
# 54384  2023-11-12T11:38:00.000-05:00         1      NaN       NaN  Sin dato
# 54385  2023-11-15T12:30:00.000-05:00         1      NaN       NaN  Sin dato
# 54386  2023-11-16T16:03:00.000-05:00         1      NaN       NaN  Sin dato
# 54387  2023-11-17T06:30:00.000-05:00         1      NaN       NaN  Sin dato
# 54388  2023-11-17T07:00:00.000-05:00         1      NaN       NaN  Sin dato
# 54389  2023-11-17T17:30:00.000-05:00         1      NaN       NaN  Sin dato
# ...

# %%
DF_hurtos_establecimiento_MED.isna()  ## Realiza la misma funcion del metodo ISNULL
# Out:
#        fecha_hecho  cantidad  latitud  longitud   sexo   edad  estado_civil  \
# 0            False     False    False     False  False  False         False
# 1            False     False    False     False  False  False         False
# 2            False     False    False     False  False  False         False
# 3            False     False    False     False  False  False         False
# 4            False     False    False     False  False  False         False
# ...            ...       ...      ...       ...    ...    ...           ...
# 54394        False     False     True      True  False  False         False
# 54395        False     False     True      True  False  False         False
# 54396        False     False     True      True  False  False         False
# 54397        False     False     True      True  False  False         False
# 54398        False     False     True      True  False  False         False
#
# ...

# %%
## Metodo LOC sirve para acceder a un registro de acuerdo a su indice (INDEX) y columna
## pero CON LETRAS
DF_hurtos_establecimiento_MED.loc[0]
# Out:
# fecha_hecho                              2017-01-01T16:00:00.000-05:00
# cantidad                                                             1
# latitud                                                       6.250662
# longitud                                                    -75.572558
# sexo                                                          Sin dato
# edad                                                                -1
# estado_civil                                                  Sin dato
# grupo_actor                                                   Sin dato
# actividad_delictiva                                           Sin dato
# parentesco                                                    Sin dato
# ocupacion                                                     Sin dato
# discapacidad                                                  Sin dato
# grupo_especial                                                Sin dato
# ...

# %%
## Con LOC accedo por etiquetas (accedo por letras)
DF_hurtos_establecimiento_MED.loc[20,"edad"]
# Out:
# -1

# %%
## Con ILOC accedo por posicion numerica
DF_hurtos_establecimiento_MED.iloc[1,5]
# Out:
# -1

# %%
## Metodo DUPLICATED para validar registros repetidos dentro de mi base de datos
DF_duplicados = DF_hurtos_establecimiento_MED.duplicated()
DF_duplicados
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54394    False
# 54395    False
# 54396    False
# 54397    False
# 54398    False
# Length: 54399, dtype: bool

# %%
## Contabilizar cuantos registros hay repeteidos
DF_duplicados.sum()
# Out:
# 5086

# %%
## Muestre cuales registros estan repetidos y en que columna estan
for index, value in DF_duplicados.items():  ## Itera a lo largo de los duplicados
  if value is True:   ## Si el valor es TRUE, quiere decir que es duplicado
    print(DF_hurtos_establecimiento_MED.iloc[index])  ## Busco en el DF original el registro de acuerdo a su indice
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# color                                                     Sin dato
# permiso                                                   Sin dato
# unidad_medida                                             Sin dato
# fecha_ingestion                      2024-10-06T04:06:20.000-05:00
# Name: 50339, dtype: object
# fecha_hecho                2022-08-13T02:00:00.000-05:00
# cantidad                                               1
# latitud                                         6.217295
# longitud                                      -75.502764
# sexo                                            Sin dato
# edad                                                  -1
# estado_civil                                    Sin dato
# grupo_actor                                     Sin dato
# actividad_delictiva                             Sin dato
# parentesco                                      Sin dato
# ...

# %% [markdown]
# **Borrado de columnas**

# %%
## Identificar que columnas tenemos en nuestro DF
columnas_DF = DF_hurtos_establecimiento_MED.columns
columnas_DF
# Out:
# Index(['fecha_hecho', 'cantidad', 'latitud', 'longitud', 'sexo', 'edad',
#        'estado_civil', 'grupo_actor', 'actividad_delictiva', 'parentesco',
#        'ocupacion', 'discapacidad', 'grupo_especial', 'medio_transporte',
#        'nivel_academico', 'testigo', 'conducta', 'modalidad',
#        'caracterizacion', 'conducta_especial', 'arma_medio', 'articulo_penal',
#        'categoria_penal', 'nombre_barrio', 'codigo_barrio', 'codigo_comuna',
#        'lugar', 'sede_receptora', 'bien', 'categoria_bien', 'grupo_bien',
#        'modelo', 'color', 'permiso', 'unidad_medida', 'fecha_ingestion'],
#       dtype='object')

# %%
## Identifico registros dentro de mis columnas
pd.unique(DF_hurtos_establecimiento_MED.grupo_especial)
## Informo y/o dejo evidencia sobre este campo, y su ausencia de datos
# Out:
# array(['Sin dato'], dtype=object)

# %%
pd.unique(DF_hurtos_establecimiento_MED.medio_transporte)
# Out:
# array(['Caminata', 'Motocicleta', 'Automóvil', 'Taxi', 'Autobus',
#        'Motocicleta con parrillero', 'Sin dato', 'Bicicleta', 'Planeador',
#        'Metro'], dtype=object)

# %%
## Filtrar registros
DF_hurtos_establecimiento_MED[DF_hurtos_establecimiento_MED.medio_transporte == "Planeador"]
# Out:
#                          fecha_hecho  cantidad   latitud   longitud      sexo  \
# 7828   2017-09-27T19:30:00.000-05:00         1  6.267914 -75.570105  Sin dato
# 13825  2017-12-07T04:00:00.000-05:00         1  6.197335 -75.557517  Sin dato
# 37417  2018-09-19T18:00:00.000-05:00         1  6.262362 -75.553456  Sin dato
# 41990  2018-09-19T18:00:00.000-05:00         1  6.262362 -75.553456  Sin dato
#
#        edad estado_civil grupo_actor actividad_delictiva parentesco  ...  \
# 7828     -1     Sin dato    Sin dato            Sin dato   Sin dato  ...
# 13825    -1     Sin dato    Sin dato            Sin dato   Sin dato  ...
# 37417    -1     Sin dato    Sin dato            Sin dato   Sin dato  ...
# 41990    -1     Sin dato    Sin dato            Sin dato   Sin dato  ...
#
#                                    lugar sede_receptora  \
# 7828   Institución de educación superior       Aranjuez
# 13825                   Centro comercial        Poblado
# ...

# %%
DF_hurtos_establecimiento_MED.medio_transporte == "Planeador"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54394    False
# 54395    False
# 54396    False
# 54397    False
# 54398    False
# Name: medio_transporte, Length: 54399, dtype: bool

# %%
## Imprimir todas las columnas con sus valores unicos
for i in columnas_DF:
  print(f"Valores unicos en la columna {i}:")  ## Nombro la columna a mostrar
  print(pd.unique(DF_hurtos_establecimiento_MED[i]))  ## Imprimo los valores unicos de cada columna
# Out:
# Valores unicos en la columna fecha_hecho:
# ['2017-01-01T16:00:00.000-05:00' '2017-01-01T11:00:00.000-05:00'
#  '2017-01-01T14:15:00.000-05:00' ... '2023-11-28T17:50:00.000-05:00'
#  '2023-11-29T13:30:00.000-05:00' '2023-11-30T07:30:00.000-05:00']
# Valores unicos en la columna cantidad:
# [1]
# Valores unicos en la columna latitud:
# [6.25066199 6.25723525 6.30153182 ... 6.18762465 6.27655737 6.30432005]
# Valores unicos en la columna longitud:
# [-75.57255831 -75.59973985 -75.56377139 ... -75.57247097 -75.56102522
#  -75.59678442]
# Valores unicos en la columna sexo:
# ['Sin dato', 'Hombre', 'Mujer']
# Categories (3, object): ['Hombre', 'Mujer', 'Sin dato']
# Valores unicos en la columna edad:
# [-1 22 41 56 24 23 50 27 25 36 55 35 26 43 52 29 39 45 33 34 30 37 40 38
#  42 44 54 63 62 47 31 32 46 61 60 20 28 48 19 51 21 49 69 59 16 67 18 53
#  58 64 17 79 65 57 76 66 71 68 14]
# Valores unicos en la columna estado_civil:
# ...

# %%
## Borrado de columnas sin datos
DF_hurtos_establecimiento_MED.drop(columns = ['articulo_penal'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['unidad_medida'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['permiso'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['categoria_penal'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['caracterizacion'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['testigo'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['nivel_academico'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['grupo_actor'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['actividad_delictiva'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['parentesco'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['ocupacion'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['discapacidad'], inplace=True)
DF_hurtos_establecimiento_MED.drop(columns = ['grupo_especial'], inplace=True)

# %%
DF_hurtos_establecimiento_MED.drop(columns = ['estado_civil'], inplace=True)

# %%
DF_hurtos_establecimiento_MED.drop(columns = ['sexo'], inplace=True)

# %%
DF_hurtos_establecimiento_MED
# Out:
#                          fecha_hecho  cantidad   latitud   longitud  edad  \
# 0      2017-01-01T16:00:00.000-05:00         1  6.250662 -75.572558    -1
# 1      2017-01-01T11:00:00.000-05:00         1  6.257235 -75.599740    -1
# 2      2017-01-01T14:15:00.000-05:00         1  6.301532 -75.563771    -1
# 3      2017-01-01T16:00:00.000-05:00         1  6.250662 -75.572558    -1
# 4      2017-01-01T14:15:00.000-05:00         1  6.301532 -75.563771    -1
# ...                              ...       ...       ...        ...   ...
# 54394  2023-11-27T09:30:00.000-05:00         1       NaN        NaN    -1
# 54395  2023-11-28T12:00:00.000-05:00         1       NaN        NaN    -1
# 54396  2023-11-28T17:50:00.000-05:00         1       NaN        NaN    -1
# 54397  2023-11-29T13:30:00.000-05:00         1       NaN        NaN    -1
# 54398  2023-11-30T07:30:00.000-05:00         1       NaN        NaN    -1
#
#       medio_transporte                           conducta  \
# ...

# %%
## Llamo nuevamente las columnas del DF, para que no me llame las que fueron borrados
columnas_DF_Borr = DF_hurtos_establecimiento_MED.columns

## Imprimir todas las columnas con sus valores unicos
for i in columnas_DF_Borr:
  print(f"Valores unicos en la columna {i}:")  ## Nombro la columna a mostrar
  print(pd.unique(DF_hurtos_establecimiento_MED[i]))  ## Imprimo los valores unicos de cada columna
# Out:
# Valores unicos en la columna fecha_hecho:
# ['2017-01-01T16:00:00.000-05:00' '2017-01-01T11:00:00.000-05:00'
#  '2017-01-01T14:15:00.000-05:00' ... '2023-11-28T17:50:00.000-05:00'
#  '2023-11-29T13:30:00.000-05:00' '2023-11-30T07:30:00.000-05:00']
# Valores unicos en la columna cantidad:
# [1]
# Valores unicos en la columna latitud:
# [6.25066199 6.25723525 6.30153182 ... 6.18762465 6.27655737 6.30432005]
# Valores unicos en la columna longitud:
# [-75.57255831 -75.59973985 -75.56377139 ... -75.57247097 -75.56102522
#  -75.59678442]
# Valores unicos en la columna edad:
# [-1 22 41 56 24 23 50 27 25 36 55 35 26 43 52 29 39 45 33 34 30 37 40 38
#  42 44 54 63 62 47 31 32 46 61 60 20 28 48 19 51 21 49 69 59 16 67 18 53
#  58 64 17 79 65 57 76 66 71 68 14]
# Valores unicos en la columna medio_transporte:
# ['Caminata' 'Motocicleta' 'Automóvil' 'Taxi' 'Autobus'
#  'Motocicleta con parrillero' 'Sin dato' 'Bicicleta' 'Planeador' 'Metro']
# Valores unicos en la columna conducta:
# ...

# %%
## Filtramos de acuerdo a un criterio de busqueda, con esto tenemos registros donde...
## ... fueron hurtados elementos belicos (Armas)
DF_hurtos_establecimiento_MED[
    (DF_hurtos_establecimiento_MED.bien == "Fusil") |
    (DF_hurtos_establecimiento_MED.bien == "Pistola") |
    (DF_hurtos_establecimiento_MED.bien == "Calibre munición")
        ]
# Out:
#                          fecha_hecho  cantidad   latitud   longitud  edad  \
# 2      2017-01-01T14:15:00.000-05:00         1  6.301532 -75.563771    -1
# 5      2017-01-01T14:15:00.000-05:00         1  6.301532 -75.563771    -1
# 2260   2003-11-13T07:00:00.000-05:00         1  6.232530 -75.582630    -1
# 2265   2003-11-13T07:00:00.000-05:00         1  6.232530 -75.582630    -1
# 3146   2017-02-28T00:00:00.000-05:00         1  6.188446 -75.576432    -1
# 3156   2017-03-01T08:20:00.000-05:00         1  6.248742 -75.573862    -1
# 3783   2017-04-15T23:45:00.000-05:00         1  6.234067 -75.574436    -1
# 6210   2004-01-13T07:30:00.000-05:00         1  6.238448 -75.573970    -1
# 6215   2004-01-13T07:30:00.000-05:00         1  6.238448 -75.573970    -1
# 6632   2004-04-19T07:35:00.000-05:00         1  6.210008 -75.590606    -1
# 6635   2004-04-19T07:35:00.000-05:00         1  6.210008 -75.590606    -1
# 8120   2017-10-14T12:25:00.000-05:00         1  6.225812 -75.596903    -1
# ...

# %%
## Reemplazamos el registro Rompimiento cerraduta por Rompimiento cerradura
DF_hurtos_establecimiento_MED.replace({"Rompimiento cerraduta":"Rompimiento cerradura"}, inplace = True)
# Out:
# <ipython-input-56-1d65f3874942>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   DF_hurtos_establecimiento_MED.replace({"Rompimiento cerraduta":"Rompimiento cerradura"}, inplace = True)

# %%
## Reemplazamos el registro -1 por None
DF_hurtos_establecimiento_MED['edad'] = DF_hurtos_establecimiento_MED['edad'].replace(-1, None)

# %%
pd.unique(DF_hurtos_establecimiento_MED.edad)
# Out:
# array([nan, 22., 41., 56., 24., 23., 50., 27., 25., 36., 55., 35., 26.,
#        43., 52., 29., 39., 45., 33., 34., 30., 37., 40., 38., 42., 44.,
#        54., 63., 62., 47., 31., 32., 46., 61., 60., 20., 28., 48., 19.,
#        51., 21., 49., 69., 59., 16., 67., 18., 53., 58., 64., 17., 79.,
#        65., 57., 76., 66., 71., 68., 14.])

# %%
## Llamo nuevamente las columnas del DF, para que no me llame las que fueron borrados
columnas_DF_Borr = DF_hurtos_establecimiento_MED.columns

## Imprimir todas las columnas con sus valores unicos
for i in columnas_DF_Borr:
  print(f"Valores unicos en la columna {i}:")  ## Nombro la columna a mostrar
  print(pd.unique(DF_hurtos_establecimiento_MED[i]))  ## Imprimo los valores unicos de cada columna
# Out:
# Valores unicos en la columna fecha_hecho:
# ['2017-01-01T16:00:00.000-05:00' '2017-01-01T11:00:00.000-05:00'
#  '2017-01-01T14:15:00.000-05:00' ... '2023-11-28T17:50:00.000-05:00'
#  '2023-11-29T13:30:00.000-05:00' '2023-11-30T07:30:00.000-05:00']
# Valores unicos en la columna cantidad:
# [1]
# Valores unicos en la columna latitud:
# [6.25066199 6.25723525 6.30153182 ... 6.18762465 6.27655737 6.30432005]
# Valores unicos en la columna longitud:
# [-75.57255831 -75.59973985 -75.56377139 ... -75.57247097 -75.56102522
#  -75.59678442]
# Valores unicos en la columna edad:
# [nan 22. 41. 56. 24. 23. 50. 27. 25. 36. 55. 35. 26. 43. 52. 29. 39. 45.
#  33. 34. 30. 37. 40. 38. 42. 44. 54. 63. 62. 47. 31. 32. 46. 61. 60. 20.
#  28. 48. 19. 51. 21. 49. 69. 59. 16. 67. 18. 53. 58. 64. 17. 79. 65. 57.
#  76. 66. 71. 68. 14.]
# Valores unicos en la columna medio_transporte:
# ['Caminata' 'Motocicleta' 'Automóvil' 'Taxi' 'Autobus'
# ...
