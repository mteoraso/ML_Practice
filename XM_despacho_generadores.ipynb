# %% [markdown]
# <a href="https://colab.research.google.com/github/mteoraso/Practicas_DataScience/blob/EDA-Projects/XM_despacho_generadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydataxm
# Out:
# Collecting pydataxm
#   Downloading pydataxm-0.3.11.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pydataxm) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pydataxm) (2.2.2)
# Collecting datetime (from pydataxm)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from pydataxm) (3.11.13)
# Collecting asyncio (from pydataxm)
#   Downloading asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from pydataxm) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.18.3)
# Collecting zope.interface (from datetime->pydataxm)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from datetime->pydataxm) (2025.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pydataxm) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pydataxm) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pydataxm) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pydataxm) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface->datetime->pydataxm) (75.1.0)
# Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 1.7 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.3 MB/s eta 0:00:00
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: pydataxm
#   Building wheel for pydataxm (setup.py) ... done
#   Created wheel for pydataxm: filename=pydataxm-0.3.11-py3-none-any.whl size=10731 sha256=1af0db0961a69af8023cb364aaacb34f9dca7aa576d4ed6dc70b0a0257e08fe5
#   Stored in directory: /root/.cache/pip/wheels/7d/70/75/6da4301bf3c954a6c22b2e7bc7d5bda39a42cd5d5ea7e0cf18
# Successfully built pydataxm
# Installing collected packages: asyncio, zope.interface, datetime, pydataxm
# Successfully installed asyncio-3.4.3 datetime-5.5 pydataxm-0.3.11 zope.interface-7.2

# %%
# Importación
from pydataxm.pydatasimem import ReadSIMEM, CatalogSIMEM

# Buscar el id del conjunto de datos
catalogo = CatalogSIMEM('Datasets')
data_catalogo = catalogo.get_data()
print(data_catalogo.query("nombreConjuntoDatos.str.contains('Generación Real')"))

# Crear una instancia de ReadSIMEM
dataset_id = 'E17D25'
fecha_inicio = '2024-04-01'
fecha_fin = '2024-04-30'
generacion = ReadSIMEM(dataset_id, fecha_inicio, fecha_fin)

# Recuperar datos
data = generacion.main(filter=False)
print(data)
# Out:
#     idDataset                                nombreConjuntoDatos  \
# 226    E17D25  Generación Real y Programada en las Plantas de...
#
#            fechaPublicacion      fechaActualizacion           inicioDato  \
# 226  2023-09-29T10:59:40.38  2025-03-09T11:18:50.56  2013-01-01T00:00:00
#
#                  finDato            fechaDescarga  \
# 226  2025-03-07T00:00:00  2025-03-07T13:48:25.177
#
#                                         urlConexionAPI  \
# 226  https://www.simem.coPublicData?startDate=2025-...
#
#                                       urlConjuntoDatos tipoPublicacion
# 226  https://www.simem.co/datadetail/e17d259d-ffba-...         Público
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Generación Real y Programada en las Plantas de Generación"
# Start of asynchronous data extraction
# End of data extracting process
# ****************************************************************************************************
#            Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 0     2024-04-30         3HLD          Solar             Solar
# 1     2024-04-30         3GVI          Solar             Solar
# 2     2024-04-30         3K6T          Solar             Solar
# 3     2024-04-30         3J4R          Solar             Solar
# 4     2024-04-30         3IS2          Solar             Solar
# ...          ...          ...            ...               ...
# 9757  2024-04-01         CRC1     Hidraulica        Hidraulica
# 9758  2024-04-01         2QV2     Hidraulica        Hidraulica
# 9759  2024-04-01         2YNA     Hidraulica        Hidraulica
# 9760  2024-04-01         2V5G     Hidraulica        Hidraulica
# 9761  2024-04-01         SNS1     Hidraulica        Hidraulica
#
#              TipoDespachoRecurso  GeneracionRealEstimada  \
# 0     No Despachado Centralmente                43896.92
# 1     No Despachado Centralmente               155235.44
# 2     No Despachado Centralmente                57742.14
# 3     No Despachado Centralmente                72670.67
# 4     No Despachado Centralmente                15482.22
# ...                          ...                     ...
# 9757  No Despachado Centralmente                88848.64
# 9758  No Despachado Centralmente               134110.80
# 9759  No Despachado Centralmente                25788.97
# 9760  No Despachado Centralmente                10518.37
# 9761  No Despachado Centralmente                    0.00
#
#       GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                          70840.0                         70840.0
# 1                           6000.0                          6000.0
# 2                          58390.0                         58390.0
# 3                          78550.0                         78550.0
# 4                          12900.0                         12900.0
# ...                            ...                             ...
# 9757                       90000.0                         90000.0
# 9758                        8000.0                          8000.0
# 9759                       74400.0                         74400.0
# 9760                        6960.0                          6960.0
# 9761                           0.0                             0.0
#
# [9762 rows x 8 columns]

# %%
data
# Out:
#            Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 0     2024-04-30         3HLD          Solar             Solar
# 1     2024-04-30         3GVI          Solar             Solar
# 2     2024-04-30         3K6T          Solar             Solar
# 3     2024-04-30         3J4R          Solar             Solar
# 4     2024-04-30         3IS2          Solar             Solar
# ...          ...          ...            ...               ...
# 9757  2024-04-01         CRC1     Hidraulica        Hidraulica
# 9758  2024-04-01         2QV2     Hidraulica        Hidraulica
# 9759  2024-04-01         2YNA     Hidraulica        Hidraulica
# 9760  2024-04-01         2V5G     Hidraulica        Hidraulica
# 9761  2024-04-01         SNS1     Hidraulica        Hidraulica
#
#              TipoDespachoRecurso  GeneracionRealEstimada  \
# 0     No Despachado Centralmente                43896.92
# 1     No Despachado Centralmente               155235.44
# 2     No Despachado Centralmente                57742.14
# 3     No Despachado Centralmente                72670.67
# 4     No Despachado Centralmente                15482.22
# ...                          ...                     ...
# 9757  No Despachado Centralmente                88848.64
# 9758  No Despachado Centralmente               134110.80
# 9759  No Despachado Centralmente                25788.97
# 9760  No Despachado Centralmente                10518.37
# 9761  No Despachado Centralmente                    0.00
#
#       GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                          70840.0                         70840.0
# 1                           6000.0                          6000.0
# 2                          58390.0                         58390.0
# 3                          78550.0                         78550.0
# 4                          12900.0                         12900.0
# ...                            ...                             ...
# 9757                       90000.0                         90000.0
# 9758                        8000.0                          8000.0
# 9759                       74400.0                         74400.0
# 9760                        6960.0                          6960.0
# 9761                           0.0                             0.0
#
# [9762 rows x 8 columns]

# %%
# Crear una instancia de ReadSIMEM
dataset_id = 'E17D25'
fecha_inicio = '2024-01-01'
fecha_fin = '2024-04-30'
generacion = ReadSIMEM(dataset_id, fecha_inicio, fecha_fin)

# Recuperar datos
data = generacion.main(filter=False)
print(data)
# Out:
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Generación Real y Programada en las Plantas de Generación"
# Start of asynchronous data extraction
# End of data extracting process
# ****************************************************************************************************
#             Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 0      2024-01-31         SNCR     Hidraulica        Hidraulica
# 1      2024-01-31         BAR1     Hidraulica        Hidraulica
# 2      2024-01-31         ESMR     Hidraulica      FILO DE AGUA
# 3      2024-01-31         PRV1     Hidraulica        Hidraulica
# 4      2024-01-31         TVL1        Termica   CICLO COMBINADO
# ...           ...          ...            ...               ...
# 38447  2024-04-03         3IS2          Solar             Solar
# 38448  2024-04-03         3J4R          Solar             Solar
# 38449  2024-04-03         3K6T          Solar             Solar
# 38450  2024-04-03         3GVI          Solar             Solar
# 38451  2024-04-03         3HLD          Solar             Solar
#
#               TipoDespachoRecurso  GeneracionRealEstimada  \
# 0         Despachado Centralmente             23394896.00
# 1      No Despachado Centralmente               138056.06
# 2         Despachado Centralmente               380281.78
# 3      No Despachado Centralmente                72083.49
# 4         Despachado Centralmente              5547343.00
# ...                           ...                     ...
# 38447  No Despachado Centralmente                10416.93
# 38448  No Despachado Centralmente                37822.30
# 38449  No Despachado Centralmente                    0.00
# 38450  No Despachado Centralmente               110347.73
# 38451  No Despachado Centralmente                36299.62
#
#        GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                        23363000.0                      23363000.0
# 1                               0.0                             0.0
# 2                          576000.0                        362000.0
# 3                               0.0                             0.0
# 4                         5736000.0                       5736000.0
# ...                             ...                             ...
# 38447                        9601.0                         12900.0
# 38448                       78550.0                         78550.0
# 38449                       58390.0                         58390.0
# 38450                      138000.0                        138000.0
# 38451                       70840.0                         70840.0
#
# [38452 rows x 8 columns]

# %%
import pandas as pd
pd.unique(data['Fecha'])
# Out:
# array(['2024-01-31', '2024-01-30', '2024-01-29', '2024-01-28',
#        '2024-01-27', '2024-01-26', '2024-01-25', '2024-01-24',
#        '2024-01-23', '2024-01-22', '2024-01-21', '2024-01-20',
#        '2024-01-19', '2024-01-18', '2024-01-17', '2024-01-16',
#        '2024-01-15', '2024-01-14', '2024-01-13', '2024-01-12',
#        '2024-01-11', '2024-01-10', '2024-01-09', '2024-01-08',
#        '2024-01-07', '2024-01-06', '2024-01-05', '2024-01-04',
#        '2024-01-03', '2024-01-02', '2024-01-01', '2024-03-02',
#        '2024-03-01', '2024-02-29', '2024-02-28', '2024-02-27',
#        '2024-02-26', '2024-02-25', '2024-02-24', '2024-02-23',
#        '2024-02-22', '2024-02-21', '2024-02-20', '2024-02-19',
#        '2024-02-18', '2024-02-17', '2024-02-16', '2024-02-15',
#        '2024-02-14', '2024-02-13', '2024-02-12', '2024-02-11',
#        '2024-02-10', '2024-02-09', '2024-02-08', '2024-02-07',
#        '2024-02-06', '2024-02-05', '2024-02-04', '2024-02-03',
#        '2024-02-02', '2024-02-01', '2024-04-02', '2024-04-01',
#        '2024-03-31', '2024-03-30', '2024-03-29', '2024-03-28',
#        '2024-03-27', '2024-03-26', '2024-03-25', '2024-03-24',
#        '2024-03-23', '2024-03-22', '2024-03-21', '2024-03-20',
#        '2024-03-19', '2024-03-18', '2024-03-17', '2024-03-16',
#        '2024-03-15', '2024-03-14', '2024-03-13', '2024-03-12',
#        '2024-03-11', '2024-03-10', '2024-03-09', '2024-03-08',
#        '2024-03-07', '2024-03-06', '2024-03-05', '2024-03-04',
#        '2024-03-03', '2024-04-30', '2024-04-29', '2024-04-28',
#        '2024-04-27', '2024-04-26', '2024-04-25', '2024-04-24',
#        '2024-04-23', '2024-04-22', '2024-04-21', '2024-04-20',
#        '2024-04-19', '2024-04-18', '2024-04-17', '2024-04-16',
#        '2024-04-15', '2024-04-14', '2024-04-13', '2024-04-12',
#        '2024-04-11', '2024-04-10', '2024-04-09', '2024-04-08',
#        '2024-04-07', '2024-04-06', '2024-04-05', '2024-04-04',
#        '2024-04-03'], dtype=object)

# %%
data_2024_1_31 = data[data['Fecha'] == '2024-01-31']
data_2024_1_31
# Out:
#           Fecha CodigoPlanta TipoGeneracion      TipoClasificacion  \
# 0    2024-01-31         SNCR     Hidraulica             Hidraulica
# 1    2024-01-31         BAR1     Hidraulica             Hidraulica
# 2    2024-01-31         ESMR     Hidraulica           FILO DE AGUA
# 3    2024-01-31         PRV1     Hidraulica             Hidraulica
# 4    2024-01-31         TVL1        Termica        CICLO COMBINADO
# ..          ...          ...            ...                    ...
# 303  2024-01-31         SFC1     Hidraulica  GENERADOR DISTRIBUIDO
# 304  2024-01-31         3J2H          Solar                  Solar
# 305  2024-01-31         3DSO          Solar                  Solar
# 306  2024-01-31         IQU1     Hidraulica             Hidraulica
# 307  2024-01-31         CUC1     Hidraulica           FILO DE AGUA
#
#             TipoDespachoRecurso  GeneracionRealEstimada  \
# 0       Despachado Centralmente             23394896.00
# 1    No Despachado Centralmente               138056.06
# 2       Despachado Centralmente               380281.78
# 3    No Despachado Centralmente                72083.49
# 4       Despachado Centralmente              5547343.00
# ..                          ...                     ...
# 303  No Despachado Centralmente                 5083.77
# 304  No Despachado Centralmente                22257.29
# 305  No Despachado Centralmente                54486.11
# 306  No Despachado Centralmente                32577.37
# 307     Despachado Centralmente               189259.05
#
#      GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                      23363000.0                      23363000.0
# 1                             0.0                             0.0
# 2                        576000.0                        362000.0
# 3                             0.0                             0.0
# 4                       5736000.0                       5736000.0
# ..                            ...                             ...
# 303                        5190.0                          5190.0
# 304                       75230.0                         75230.0
# 305                       94000.0                         94000.0
# 306                       24000.0                         24000.0
# 307                     1344000.0                        192000.0
#
# [308 rows x 8 columns]

# %%
data_2024_1_31.groupby(["TipoGeneracion"]).size()
# Out:
# TipoGeneracion
# Cogenerador     12
# Eolica           3
# Hidraulica     159
# Solar           68
# Termica         66
# dtype: int64

# %%
data.groupby('TipoGeneracion')['GeneracionRealEstimada'].sum().sort_values()
# Out:
# TipoGeneracion
# Eolica         6.288038e+07
# Cogenerador    3.105032e+08
# Solar          9.643334e+08
# Termica        1.020888e+10
# Hidraulica     1.597386e+10
# Name: GeneracionRealEstimada, dtype: float64

# %%
data.groupby('TipoGeneracion')['GeneracionProgramadaDespacho'].sum().sort_values()
# Out:
# TipoGeneracion
# Eolica         6.783214e+07
# Cogenerador    3.255474e+08
# Solar          1.063878e+09
# Termica        1.036082e+10
# Hidraulica     1.512353e+10
# Name: GeneracionProgramadaDespacho, dtype: float64

# %%
data[data['TipoGeneracion'] == 'Eolica']
# Out:
#             Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 109    2024-01-31         3EE4         Eolica            Eolica
# 141    2024-01-31         3EXH         Eolica            Eolica
# 302    2024-01-31         JPR1         Eolica            Eolica
# 385    2024-01-30         JPR1         Eolica            Eolica
# 541    2024-01-30         3EE4         Eolica            Eolica
# ...           ...          ...            ...               ...
# 37923  2024-04-04         3EE4         Eolica            Eolica
# 37924  2024-04-04         JPR1         Eolica            Eolica
# 38289  2024-04-03         3EE4         Eolica            Eolica
# 38290  2024-04-03         JPR1         Eolica            Eolica
# 38411  2024-04-03         3EXH         Eolica            Eolica
#
#               TipoDespachoRecurso  GeneracionRealEstimada  \
# 109    No Despachado Centralmente               259091.59
# 141    No Despachado Centralmente               185909.03
# 302    No Despachado Centralmente                    0.00
# 385    No Despachado Centralmente                    0.00
# 541    No Despachado Centralmente               249711.11
# ...                           ...                     ...
# 37923  No Despachado Centralmente               250636.72
# 37924  No Despachado Centralmente                    0.00
# 38289  No Despachado Centralmente               282326.84
# 38290  No Despachado Centralmente                    0.00
# 38411  No Despachado Centralmente               134648.48
#
#        GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 109                        291840.0                        291840.0
# 141                        210140.0                        210140.0
# 302                             0.0                             0.0
# 385                             0.0                             0.0
# 541                        315590.0                        315590.0
# ...                             ...                             ...
# 37923                      314530.0                        314530.0
# 37924                           0.0                             0.0
# 38289                      324170.0                        359520.0
# 38290                           0.0                             0.0
# 38411                      212950.0                        239060.0
#
# [363 rows x 8 columns]

# %%
data['GeneracionRealEstimada'].sum()
# Out:
# 27520455825.45

# %%
data['GeneracionProgramadaRedespacho'].sum()
# Out:
# 26905673681.760002

# %%
data['GeneracionProgramadaDespacho'].sum() - data['GeneracionRealEstimada'].sum()
# Out:
# -578853249.050003

# %%
data['GeneracionProgramadaDespacho'].mean()
# Out:
# 700655.4295329241

# %%
data['GeneracionProgramadaDespacho'].std()
# Out:
# 2340199.612292527
